# %% [markdown]
# <a href="https://colab.research.google.com/github/Anmoltech0407/DSVLAB/blob/main/DSV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 1. Load the dataset (assuming 'dataset.csv' is available, otherwise use 'iris.csv' from context)
df = pd.read_csv('/content/iris.csv')

# 2. Display basic dataset details
print("--- Dataset Head ---")
print(df.head())

# 3. Structural Information
print("--- Dataset Info ---")
print(df.info())

# 4. Summary Statistics
print("--- Summary Statistics ---")
print(df.describe())

# 5. Missing Values Count
print("--- Missing Values Count ---")
print(df.isnull().sum())
