# %% [markdown]
# <a href="https://colab.research.google.com/github/Anmoltech0407/DSVLAB/blob/main/DSV_Lab_Experiment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment 2-Python Fundamentals

# %% [markdown]
# #TOPIC 1: Variables & Dynamic Typing

# %% [markdown]
# Ques 01

# %%
age=25
print("Age=",age)
print("Type=",type(age))
# Out:
# Age= 25
# Type= <class 'int'>

# %% [markdown]
# Ques 02

# %%
num="10"
print("Num=",num)
print("Type=",type(num))

num=10
print("num=",num)
print("Type=",type(num))
# Out:
# Num= 10
# Type= <class 'str'>
# num= 10
# Type= <class 'int'>

# %% [markdown]
# Ques 03

# %%
x=3
print("Value:",x)
print("Type:",type(x))
x=4.5
print("Value:",x)
print("Type:",type(x))
# Out:
# Value: 3
# Type: <class 'int'>
# Value: 4.5
# Type: <class 'float'>

# %% [markdown]
# Ques 04

# %%
x=5
x="five"
print(x)
# Out:
# five

# %% [markdown]
# # TOPIC 02 : Common Data Types

# %% [markdown]
# Ques 01

# %%
a=10
b=3.14
c="hello"
d=True
e=[1,2,3]
print(a,type(a))
print(b,type(b))
print(c,type(c))
print(d,type(d))
print(e,type(e))
# Out:
# 10 <class 'int'>
# 3.14 <class 'float'>
# hello <class 'str'>
# True <class 'bool'>
# [1, 2, 3] <class 'list'>

# %% [markdown]
# Ques 02

# %%
a=[1,2,3]
b=(1,2,3)
a[0]=7
print(a)
print(b)
# Out:
# [7, 2, 3]
# (1, 2, 3)

# %% [markdown]
# Ques 03

# %%
price=499.99
in_stock=False

if (in_stock):
  print("Available")
else:
  print("Not Available")
# Out:
# Not Available

# %% [markdown]
# #Topic 03 : Objects,Identity(is) vs Equality(--)

# %% [markdown]
# Ques 01

# %%
x=[1,2,3,]
y=[1,2,3]
print(x==y)
print(x is y)
# Out:
# True
# False

# %% [markdown]
# Ques 02

# %%
a=[1,2,3,4]
b=[1,2,3,4]
print(a==b)
print(a is b)
# Out:
# True
# False

# %% [markdown]
# Ques 03

# %%
x=100
y=100
print("x is y:",x is y)
print("x==y:",x==y)

p=1000
q=1000
print("p is q:",p is q)
print("p ==q:",p==q)
# Out:
# x is y: True
# x==y: True
# p is q: False
# p ==q: True

# %% [markdown]
# Ques 04

# %%
# print("Type of 5:",type(5))
# print("Type of 'hi':",type ("hi"))
# print("Type of [1,2]:",type ([1,2]))
# Out:
# Type of 5: <class 'int'>
# Type of 'hi': <class 'str'>
# Type of [1,2]: <class 'list'>

# %% [markdown]
# #Topic 04: Strings & Methods

# %% [markdown]
# Ques 01

# %%
name="pYTHOn"
print(name.upper())
print(name.lower())
print(name.title())
# Out:
# PYTHON
# python
# Python

# %% [markdown]
# Ques 02

# %%
s="Hello"
s.lower()
print(s)
# Out:
# Hello

# %% [markdown]
# Ques 03

# %%
s="Hello"
s=s.lower()
print(s)
# Out:
# hello

# %% [markdown]
# Ques 04

# %%
sentence="Learning Python is fun"
sentence=sentence.strip()
print(sentence.strip())
print(sentence.count("n"))
print(sentence.split())
# Out:
# Learning Python is fun
# 4
# ['Learning', 'Python', 'is', 'fun']

# %% [markdown]
# #Topic 05: Loops-- for,range(),While

# %% [markdown]
# Ques 01
